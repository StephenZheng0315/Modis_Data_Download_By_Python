# %% [markdown]
# # Step 1
# Log in to your account, click Profile, click App Keys. Enter the key that Modis gets in Description.
#
# <img src = "https://pic4.zhimg.com/80/v2-972762c50d7db50223e39473b5559587_hd.jpg">
# At this point, the preparations are done!
#
# The key sptography obtained is as follows F*******-****-****-****-D****D*****C
#
# # Step 2
# And then log in <a src = "https://ladsweb.modaps.eosdis.nasa.gov/search/">the Website</a>
# Click in order of steps:
# 1.PRODUCTS
# 2.TIME
# 3.LOCATION
# 4.FILES
# 5.REVIEW and ORDER
#
# <img src = "https://pic2.zhimg.com/80/v2-07f4fed1bae9e589bc3471bf96bec6a5_hd.png">
#
# 1.Products
#
# Here I choose `mod04-3km` data from `Terra` satellite aerosol products.
#
#     Click on the right i symbol to see information about the satellite
#
#
# <img src = "https://pic3.zhimg.com/80/v2-6164b0d26457b20982551e4f776181be_hd.jpg">
#
# 2.TIME
#
# Choose a time, a total of two options (time period and single day), please explore yourself (lazy hahaha). I chose 20190601 - 20190625
#
# <img src = "https://pic2.zhimg.com/80/v2-a0db7456a232299c5b4c29bb435dc699_hd.jpg">
#
# 3.LOCATION
#
# <img src = "https://pic1.zhimg.com/80/v2-108449cd033ad64583da482a8a69c378_hd.jpg">
#
# 4.FILES
#
# Click `Select All`
#
#
# <img src = "https://pic1.zhimg.com/80/v2-00464e27a9ef692fc4ae6d0660fcadbc_hd.jpg">
#
# 5.REVIEW and ORDER
#
# After the final Submit Order, the Modis takeaway you ordered was delivered to your mailbox~~~~~~~
#
#
# <img src = "https://pic2.zhimg.com/80/v2-3f76079c6c8f5295bc7bff3e316378c9_hd.jpg">
#
# After the order is submitted successfully, the registration mailbox receives an email.
#
# <img src = "https://pic1.zhimg.com/80/v2-b026ed87dcc8727291bd8bca548bf008_hd.png">
#
# <img src = "https://pic2.zhimg.com/80/v2-9018c4ac7511ac4ae1ad1f68802ec5f9_hd.jpg">
#
# Go to the arrow page and download the corresponding python version of the tool.
# To avoid trouble, I have prepared `python laads-data-download.py` in this project.
#
# <img src = "https://pic2.zhimg.com/80/v2-911e3c5a2251c42a1d68b3404e4c1159_hd.jpg">
#
# Personally, it is recommended that the code be present inside Jupyter.
#
# But after following the official tip to remove the .txt extension, we got the script we needed!!!!
#
# Next up is the stage of downloading the data. Copy the order number, view the download link
#
# <img src = "https://pic2.zhimg.com/80/v2-692e2259710bb91d9c84834e1e8197b9_hd.jpg">
#
#
# You need to switch to the directory where the script is located before opening the cmd runner.
#
# <img src = "https://pic2.zhimg.com/80/v2-0a7d9f454d82887ef0e52c09999134dd_hd.jpg">
#
# The input format as follow:
#
# ```python
# python laads-data-download.py -s https://ladsweb.modaps.eosdis.nasa.gov/archive/orders/501348842/ -d D:\balabala -t F*******-****-****-****-D****D*****C
# ```
#
# Finally, explain the parameters used for the operation:
#
# ```python
# This script will recursively download all files if they don't exist from a
# LAADS URL and stores them to the specified path
#
# optional arguments:
#   -h,     show this help message and exit
#   -s URL,  Recursively download files at URL
#   -d DIR,  Store directory structure in DIR
#   -t TOK,  Use app token TOK to authenticate
# ```
